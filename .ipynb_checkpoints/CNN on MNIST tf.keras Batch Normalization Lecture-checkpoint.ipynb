# %% [markdown]
# # Deep Learning
#
#
# ### Neural Networks
# A neural network is composed of layers, each containing neurons or units as they are called nowadays, see image. The goal in Deep Learning is to create powerful models that learn features in the input data. A neural network is a function composition of layers.

# %%
from IPython.display import Image
Image(filename="DeepLearn.png")

# %% [markdown]
# ## Convolutional Neural Networks
# In computer vision convolutional neural networks are used for example in image classification, object detection, image captioning and semantic segmentation among other things.
#
# The principal components in an CNN are:
# * convolution layers
# * max or average pooling
# * full connected layers

# %% [markdown]
# ### Convolutional layer

# %%
Image(filename="convolution.png")

# %%
import tensorflow as tf
from functools import partial
from tensorflow import keras
import numpy as np
tf.random.set_seed(42)

# %% [markdown]
# Download data from keras. Use the cifar 10.

# %% [raw]
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
fashion_mnist = keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

num_classes = 10

# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
# y_train = np.expand_dims(y_train, -1)
y_test = keras.utils.to_categorical(y_test, num_classes)
# y_test = np.expand_dims(y_test, -1)

# %%
x_train.shape, x_train[0, :, :].max(), x_train[0, :, :].min()
# Out:
# ((60000, 28, 28, 1), 255, 0)

# %%
x_train, x_test = x_train/255.0, x_test/255.0

# %% [markdown]
# # Create model

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch/s)
    return exponential_decay_fn

# %%
def create_cnn(activation='relu',
               padding='same', 
               input_shape=[28, 28, 1], 
               output_dim=10):
    """Create convolutional neural network"""
    model = tf.keras.Sequential()
    
    partial_cnn = partial(tf.keras.layers.Conv2D, activation=activation, padding=padding)
    
    model.add(partial_cnn(64, 7, input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(2))
    model.add(partial_cnn(128, 3))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(partial_cnn(128, 3))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(2))
    model.add(partial_cnn(256, 3))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(partial_cnn(256, 3))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(output_dim, activation='softmax'))
    
    optimizer = tf.keras.optimizers.Nadam()

    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = create_cnn()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        3200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               295040
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,417,162
# Trainable params: 1,415,498
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28, 1), (60000, 10))

# %% [markdown]
# # Train Model

# %%
exponential_decay_fn = exponential_decay(lr0=0.1, s=10)
exp_schedule = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10)

callbacks = [early_stopping,
             exp_schedule]

history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    epochs=100, 
                    batch_size=32, 
                    callbacks=callbacks
                   )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 179s 3ms/sample - loss: 5.2202 - accuracy: 0.1023 - val_loss: 2.3163 - val_accuracy: 0.1000
# Epoch 2/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 3.0980 - accuracy: 0.1020 - val_loss: 2.3162 - val_accuracy: 0.1000
# Epoch 3/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3354 - accuracy: 0.0996 - val_loss: 2.3150 - val_accuracy: 0.1000
# Epoch 4/100
# 60000/60000 [==============================] - 180s 3ms/sample - loss: 2.3122 - accuracy: 0.0987 - val_loss: 2.3069 - val_accuracy: 0.1000
# Epoch 5/100
# 60000/60000 [==============================] - 178s 3ms/sample - loss: 2.3074 - accuracy: 0.0987 - val_loss: 2.3065 - val_accuracy: 0.1000
# Epoch 6/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.5120 - accuracy: 0.1003 - val_loss: 2.3078 - val_accuracy: 0.1000
# Epoch 7/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.5926 - accuracy: 0.0995 - val_loss: 2.3083 - val_accuracy: 0.1000
# Epoch 8/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.7862 - accuracy: 0.1006 - val_loss: 2.3057 - val_accuracy: 0.1000
# Epoch 9/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3048 - accuracy: 0.0989 - val_loss: 2.3045 - val_accuracy: 0.1000
# Epoch 10/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.3043 - accuracy: 0.1016 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 11/100
# 60000/60000 [==============================] - 179s 3ms/sample - loss: 2.3040 - accuracy: 0.0986 - val_loss: 2.3040 - val_accuracy: 0.1000
# Epoch 12/100
# 60000/60000 [==============================] - 178s 3ms/sample - loss: 2.5224 - accuracy: 0.0991 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 13/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.3119 - accuracy: 0.0989 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 14/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3033 - accuracy: 0.0989 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 15/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3033 - accuracy: 0.0981 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 16/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3031 - accuracy: 0.0985 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 17/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3030 - accuracy: 0.0997 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 18/100
# 60000/60000 [==============================] - 179s 3ms/sample - loss: 2.3029 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 19/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 20/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.3027 - accuracy: 0.0997 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 21/100
# 60000/60000 [==============================] - 173s 3ms/sample - loss: 2.3575 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 22/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 23/100
# 60000/60000 [==============================] - 171s 3ms/sample - loss: 2.3027 - accuracy: 0.0972 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 24/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 25/100
# 60000/60000 [==============================] - 173s 3ms/sample - loss: 2.3026 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 26/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 27/100
# 60000/60000 [==============================] - 173s 3ms/sample - loss: 2.3026 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 28/100
# 60000/60000 [==============================] - 170s 3ms/sample - loss: 2.3348 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 29/100
# 60000/60000 [==============================] - 171s 3ms/sample - loss: 2.3026 - accuracy: 0.0970 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 30/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3026 - accuracy: 0.0975 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 31/100
# 60000/60000 [==============================] - 170s 3ms/sample - loss: 2.3026 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 32/100
# 60000/60000 [==============================] - 172s 3ms/sample - loss: 2.3026 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 33/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3026 - accuracy: 0.0980 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 34/100
# 60000/60000 [==============================] - 173s 3ms/sample - loss: 2.3026 - accuracy: 0.0993 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 35/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3041 - accuracy: 0.0974 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 36/100
# 60000/60000 [==============================] - 174s 3ms/sample - loss: 2.3026 - accuracy: 0.0964 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 37/100
# 60000/60000 [==============================] - 172s 3ms/sample - loss: 2.3026 - accuracy: 0.0966 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 38/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3026 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 39/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.7478 - accuracy: 0.0965 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 40/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3026 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 41/100
# 60000/60000 [==============================] - 177s 3ms/sample - loss: 2.3026 - accuracy: 0.0968 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 42/100
# 60000/60000 [==============================] - 178s 3ms/sample - loss: 2.3026 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 43/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3026 - accuracy: 0.0991 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 44/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3026 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 45/100
# 60000/60000 [==============================] - 173s 3ms/sample - loss: 2.3111 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 46/100
# 60000/60000 [==============================] - 176s 3ms/sample - loss: 2.3026 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.1000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5), grid=True)
plt.gca().set_ylim(0, 1)
plt.show();

# %% [markdown]
# ### Exercise
# Replace batch-normalization with the SELU activation function. Is the performance better?
# * Normalize the input
# * Use LeCun normal initialization
# * Make sure that the DNN contains only a sequence of dense layers

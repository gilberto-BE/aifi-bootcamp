# %%
from preprocess_data_tf_gpu import (load_data, 
                                    time_series_split, 
                                    data_pipe)
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from kerastuner.tuners import RandomSearch, Hyperband
from lstm_hyperband import LSTMHyperModel
from preprocess_data_tf_gpu import rolling_train_test
import tensorflow as tf
from postprocessing import error_metrics
import pandas as pd
import numpy as np
from lstm_tf_keras import plot_history

# %%
df = load_data(percentage=True)

# %%
print('df.shape:', df.shape)
print(df.head())
df.iloc[:, :10].plot(figsize=(15, 8));
plt.show();
# Out:
# df.shape: (10234, 47)
#             AAPL  ABBV  ABT  AMGN  AMZN  AVGO  BRK-B        BA       BAC  \
# Date
# 1980-01-02   NaN   NaN  NaN   NaN   NaN   NaN    NaN       NaN       NaN
# 1980-01-03   NaN   NaN  NaN   NaN   NaN   NaN    NaN  0.012595 -0.009259
# 1980-01-04   NaN   NaN  NaN   NaN   NaN   NaN    NaN  0.097015  0.000000
# 1980-01-07   NaN   NaN  NaN   NaN   NaN   NaN    NaN  0.036281  0.009346
# 1980-01-08   NaN   NaN  NaN   NaN   NaN   NaN    NaN  0.015318 -0.009259
#
#                  BMY  ...       PFE        PG  PM   T  UNH   V  VZ       WFC  \
# Date                  ...
# 1980-01-02       NaN  ...       NaN       NaN NaN NaN  NaN NaN NaN       NaN
# 1980-01-03 -0.010309  ...  0.000000 -0.013468 NaN NaN  NaN NaN NaN -0.014635
# 1980-01-04  0.003474  ...  0.036666  0.005119 NaN NaN  NaN NaN NaN  0.009902
# 1980-01-07  0.003459  ...  0.000000 -0.005093 NaN NaN  NaN NaN NaN  0.000000
# 1980-01-08  0.034483  ...  0.048232  0.003413 NaN NaN  NaN NaN NaN  0.004902
#
# ...

# %%
from lstm_tf_keras import LSTMHyperModel, exponential_decay

    
# try:
metrics_df = pd.DataFrame()

optim_param_dict = {}

for c in df.columns:
    optim_param = pd.DataFrame()
    first_valid = df.loc[:, c].first_valid_index()
    if df.loc[first_valid:, c].isnull().sum()/len(df) < 0.5:
        df.loc[:, c].plot(title=f'{c}');
        plt.show();
        print(c)
        print(df[c].shape)
        first_valid = df.loc[:, c].first_valid_index()
        data_dict = data_pipe(df.loc[first_valid:, c].values.reshape(-1, 1), 
                              use_tf_data=False,
                              use_transformer=True)
        
        xtrain, ytrain, xval, yval, xtest, ytest = (data_dict['xtrain'],
                                                    data_dict['ytrain'], 
                                                    data_dict['xval'],  
                                                    data_dict['yval'],  
                                                    data_dict['xtest'],
                                                    data_dict['ytest'])
        num_outputs = ytrain.shape[-1]
        hyper_lstm = None
        hyper_lstm = LSTMHyperModel(num_outputs=num_outputs)

        tuner = Hyperband(hyper_lstm,
                          objective='mean_squared_error',
                          max_epochs=10,
                          directory=f'hyperband_results\hubber_loss\stock_{c}', 
                          project_name=f'stock_{c}')

        tuner.search(xtrain, ytrain, 
                     validation_data=(xval, yval), 
                     epochs=10, 
                     batch_size=512,
                     verbose=0)

        model = tuner.get_best_models(num_models=1)[0]
        best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0].values
        best_hps = {k: [v] for k, v in best_hps.items()}
        
        optim_param_dict[c] = best_hps
        
        best_hps = pd.DataFrame.from_dict(best_hps)

        print('Best hyperparams:')
        print(best_hps)

        mse_train, mae_train, hr_train = error_metrics(model, xtrain, ytrain)
        mse_val, mae_val, hr_val = error_metrics(model, xval, yval)
        mse_test, mae_test, hr_test = error_metrics(model, xtest, ytest)
        optim_param['mse_train'] = [mse_train]
        optim_param['mae_train'] = [mae_train]
        optim_param['hr_train'] = [hr_train]
        optim_param['mse_val'] = [mse_val]
        optim_param['mae_val'] = [mae_val]
        optim_param['hr_val'] = [hr_val]
#         optim_param['mse_test'] = [mse_test]
#         optim_param['mae_test'] = [mae_test]
#         optim_param['hr_test'] = [hr_test]
        optim_param.index = [c]
        best_hps.index = [c]
        optim_param = optim_param.join(best_hps, how='outer')
        metrics_df = pd.concat([optim_param, metrics_df])
        print(metrics_df)

        print('#' * 50)
        
# except Exception as e:
#     print('An exception ocurred:', e)
# Out:
# AAPL
# (10234,)
# INFO:tensorflow:Reloading Oracle from existing project hyperband_results\hubber_loss\stock_AAPL\stock_AAPL\oracle.json
# INFO:tensorflow:Reloading Tuner from hyperband_results\hubber_loss\stock_AAPL\stock_AAPL\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Best hyperparams:
#    units activation  dropout  learning_rate  tuner/epochs  \
# 0     80       relu      0.1           0.01            10
#
#    tuner/initial_epoch  tuner/bracket  tuner/round  \
# 0                    4              2            2
#
#                      tuner/trial_id
# 0  e3dcfdb3ed7fd6f437e1a93bf621029c
#       mse_train  mae_train  hr_train   mse_val   mae_val    hr_val  units  \
# AAPL   0.000996   0.022364  0.482985  0.000271  0.011956  0.519278     80
#
#      activation  dropout  learning_rate  tuner/epochs  tuner/initial_epoch  \
# AAPL       relu      0.1           0.01            10                    4
#
#       tuner/bracket  tuner/round                    tuner/trial_id
# ...

# %% [markdown]
# ## Save parameters and results

# %%
metrics_df
# Out:
#        mse_train  mae_train  hr_train   mse_val   mae_val    hr_val  units  \
# XOM     0.000240   0.011073  0.491758  0.000134  0.008594  0.501201     90
# WMT     0.000357   0.013760  0.462193  0.000088  0.006879  0.463571    170
# WFC     0.000537   0.014632  0.439299  0.000251  0.011087  0.473979    240
# VZ      0.000317   0.013101  0.468144  0.000158  0.009972  0.474245    110
# V       0.000376   0.013216  0.476790  0.000215  0.010629  0.420613    100
# UNH     0.000824   0.019488  0.477654  0.000224  0.011242  0.527803    180
# T       0.000284   0.011863  0.476253  0.000098  0.007368  0.518650    130
# PM      0.000189   0.009404  0.515388  0.000247  0.010414  0.470752    190
# PG      0.000239   0.010613  0.494898  0.000080  0.006567  0.510809    150
# PFE     0.000338   0.013515  0.474097  0.000127  0.008364  0.506005    140
# PEP     0.000280   0.011943  0.477237  0.000074  0.006417  0.516413     80
# ...

# %%
optim_param_dict
# Out:
# {'AAPL': {'units': [80],
#   'activation': ['relu'],
#   'dropout': [0.1],
#   'learning_rate': [0.01],
#   'tuner/epochs': [10],
#   'tuner/initial_epoch': [4],
#   'tuner/bracket': [2],
#   'tuner/round': [2],
#   'tuner/trial_id': ['e3dcfdb3ed7fd6f437e1a93bf621029c']},
#  'ABBV': {'units': [160],
#   'activation': ['relu'],
#   'dropout': [0.0],
#   'learning_rate': [0.01],
#   'tuner/epochs': [10],
#   'tuner/initial_epoch': [4],
#   'tuner/bracket': [1],
#   'tuner/round': [1],
#   'tuner/trial_id': ['2489ad9e9443d437db56189116f8446b']},
#  'ABT': {'units': [40],
#   'activation': ['relu'],
#   'dropout': [0.0],
#   'learning_rate': [0.001],
#   'tuner/epochs': [10],
#   'tuner/initial_epoch': [4],
#   'tuner/bracket': [2],
#   'tuner/round': [2],
#   'tuner/trial_id': ['6f6d35ca310dc4bbb7d3255218eaf0c5']},
#  'AMGN': {'units': [150],
#   'activation': ['relu'],
#   'dropout': [0.0],
#   'learning_rate': [0.01],
#   'tuner/epochs': [4],
#   'tuner/initial_epoch': [2],
# ...

# %%
import os
metrics_df.to_csv(os.path.join(os.path.join('hyperband_results', 'hubber_loss'), 'results_20200723.csv'))

# %% [markdown]
# # Save dict with best hyper params

# %%
pd.DataFrame.from_dict(optim_param_dict)
# Out:
#                                                    AAPL  \
# units                                              [80]
# activation                                       [relu]
# dropout                                           [0.1]
# learning_rate                                    [0.01]
# tuner/epochs                                       [10]
# tuner/initial_epoch                                 [4]
# tuner/bracket                                       [2]
# tuner/round                                         [2]
# tuner/trial_id       [e3dcfdb3ed7fd6f437e1a93bf621029c]
#
#                                                    ABBV  \
# units                                             [160]
# activation                                       [relu]
# dropout                                           [0.0]
# learning_rate                                    [0.01]
# tuner/epochs                                       [10]
# tuner/initial_epoch                                 [4]
# ...

# %%
import pickle
new_hyperparams = metrics_df[['units', 'activation', 'dropout', 'learning_rate']]
print(new_hyperparams.head())
print()
hp = {}
for idx in new_hyperparams.index:
    print(idx)
    hp[idx] = new_hyperparams.loc[idx]
# Out:
#      units activation  dropout  learning_rate
# XOM     90        elu      0.2          0.010
# WMT    170       relu      0.4          0.001
# WFC    240       selu      0.0          0.001
# VZ     110       relu      0.1          0.001
# V      100       relu      0.0          0.001
#
# XOM
# WMT
# WFC
# VZ
# V
# UNH
# T
# PM
# PG
# PFE
# PEP
# ORCL
# NVDA
# MSFT
# MRK
# MO
# MMM
# MDT
# MCD
# MA
# KO
# JPM
# JNJ
# INTC
# IBM
# HON
# HD
# ^GSPC
# GOOG
# GILD
# GE
# FB
# DIS
# CVX
# CSCO
# CMCSA
# C
# BMY
# BAC
# BA
# BRK-B
# AVGO
# AMZN
# AMGN
# ABT
# ABBV
# AAPL

# %%
print(hp['XOM'].to_dict())
# Out:
# {'units': 90, 'activation': 'elu', 'dropout': 0.2, 'learning_rate': 0.01}

# %% [raw]
# with open(os.path.join('hyperband_results', 'best_hyperparams.pkl'), 'wb') as handle:
#     pickle.dump()

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import sys, os
scr_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(scr_dir)


# scr_dir = os.path.join(os.getcwd(), os.pardir, 'src/preprocessing')
# sys.path.append(scr_dir)


from loader.load import TimeSeriesLoader
import warnings
warnings.filterwarnings('ignore')

import importlib
from preprocessing.preprocess import (
    create_rolling_ts, 
    split_data, 
#     flatten
)
# import preprocessing.pt
# from preprocessing.pt import (
# #     create_rolling_ts, 
# #     split_data,
#     flatten
# )

# %% [markdown]
# ## Import data from archive

# %%
ROOT_PATH = 'C://Users/gilbe/Documents/aifi-bootcamp'
df = pd.read_csv(f'{ROOT_PATH}/data/aapl.csv')
df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('Unnamed: 0', inplace=True)
df.index.rename('Date', inplace=True)
# df.rename(columns={'Unnamed: 0', 'Date'}, inplace=True)
df.head()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# Date
# 2022-02-07 04:01:00   172.39   172.39  172.16    172.39     2886.0
# 2022-02-07 04:02:00   172.47   172.52  172.47    172.52     2645.0
# 2022-02-07 04:03:00   172.62   172.65  172.62    172.65      637.0
# 2022-02-07 04:04:00   172.68   172.68  172.56    172.56     1393.0
# 2022-02-07 04:05:00   172.51   172.51  172.49    172.49     2266.0

# %%
df.hist(figsize=(10, 4));
df.plot(figsize=(10, 4), subplots=True);

# %% [markdown]
# # Create train-val-test

# %%
data_train, data_val, data_test = split_data(df[['4. close']], train_size=.75, valid_size=.125)


xtrain, ytrain = create_rolling_ts(input_data=data_train, lookback=30, return_array=True)
xval, yval = create_rolling_ts(input_data=data_val, lookback=30)
xtest, ytest = create_rolling_ts(input_data=data_test, lookback=30)



xtrain, ytrain = np.array(xtrain), np.array(ytrain)
xval, yval = np.array(xval), np.array(yval)
xtest, ytest = np.array(xtest), np.array(ytest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4d6f438638c7> in <module>
#       2
#       3
# ----> 4 xtrain, ytrain = create_rolling_ts(input_data=data_train, lookback=30, return_array=True)
#       5 xval, yval = create_rolling_ts(input_data=data_val, lookback=30)
#       6 xtest, ytest = create_rolling_ts(input_data=data_test, lookback=30)
#
# TypeError: create_rolling_ts() got an unexpected keyword argument 'return_array'

# %%
xtrain.shape, ytrain.shape

# %%
xtrain.reshape(xtrain.shape[0], -1).shape, ytrain.reshape(ytrain.shape[0], -1).shape

# %%
xx = np.array(data_train)
xx.shape, xx[:, :-1], xx[:, -1]

# %%
# xt, yt = train_test_split(data_train, 30)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror', 
    n_estimators=800, 
    max_depth=5
)


regressor.fit(xtrain.reshape(xtrain.shape[0], -1), ytrain.reshape(ytrain.shape[0], -1))
